# %% [markdown]
# <a href="https://colab.research.google.com/github/dmitriyrayder/test/blob/main/DataScienceEcosystem.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Science Tools and Ecosystem (H1)
# ## Data Science Tools and Ecosystem H2

# %% [markdown]
# In this notebook, Data Science Tools and Ecosystem are summarized

# %% [markdown]
# **Objectives:**
#
# - List popular languages for Data Science
# - Identify commonly used libraries in Data Science
# - Create a table of Data Science tools
# - Perform basic arithmetic operations in Python
# - Convert time units (e.g., minutes to hours)

# %% [markdown]
# ## Author
#
# Rodionov Dmytro

# %% [markdown]
# Some of the popular languages that Data Scientists use are:
#
# 1. Python
# 2. R
# 3. SQL
# 4. Julia
# 5. Scala

# %% [markdown]
# Some of the commonly used libraries used by Data Scientists include:
# 1. Pandas
# 2. NumPy
# 3. Matplotlib
# 4. Scikit-learn
# 5. TensorFlow

# %% [markdown]
# | Data Science Tools |
# |--------------------|
# | Jupyter Notebook   |
# | Google Colab       |
# | RStudio            |

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python.
#
# | Data Science Tools |
# |--------------------|
# | Jupyter Notebook   |
# | Google Colab       |
# | RStudio            |

# %%
# This is a simple arithmetic expression to multiply then add integers
FA = (3 * 4) + 5
FA
# Out:
# 17

# %%
# This will convert 200 minutes to hours by dividing by 60
minutes = 200
hours = minutes / 60
hours
# Out:
# 3.3333333333333335
